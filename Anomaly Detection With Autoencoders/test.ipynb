# %%
import warnings
warnings.filterwarnings('ignore')


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.compose import make_column_transformer
from sklearn .preprocessing import StandardScaler,LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,recall_score, classification_report, confusion_matrix

import tensorflow
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11304\2142716914.py in <module>
#      13 from sklearn.metrics import accuracy_score,recall_score, classification_report, confusion_matrix
#      14
# ---> 15 import tensorflow
#      16
#
# c:\Users\tan\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\__init__.py in <module>
#      35 import typing as _typing
#      36
# ---> 37 from tensorflow.python.tools import module_util as _module_util
#      38 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      39
#
# c:\Users\tan\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\__init__.py in <module>
#      40
#      41 # Bring in subpackages.
# ---> 42 from tensorflow.python import data
#      43 from tensorflow.python import distribute
#      44 # from tensorflow.python import keras
#
# c:\Users\tan\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\data\__init__.py in <module>
#      19
#      20 # pylint: disable=unused-import
# ---> 21 from tensorflow.python.data import experimental
#      22 from tensorflow.python.data.ops.dataset_ops import AUTOTUNE
#      23 from tensorflow.python.data.ops.dataset_ops import Dataset
#
# c:\Users\tan\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\data\experimental\__init__.py in <module>
#      94
#      95 # pylint: disable=unused-import
# ---> 96 from tensorflow.python.data.experimental import service
#      97 from tensorflow.python.data.experimental.ops.batching import dense_to_ragged_batch
#      98 from tensorflow.python.data.experimental.ops.batching import dense_to_sparse_batch
#
# c:\Users\tan\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\data\experimental\service\__init__.py in <module>
#     417 """
#     418
# --> 419 from tensorflow.python.data.experimental.ops.data_service_ops import distribute
#     420 from tensorflow.python.data.experimental.ops.data_service_ops import from_dataset_id
#     421 from tensorflow.python.data.experimental.ops.data_service_ops import register_dataset
#
# c:\Users\tan\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\data\experimental\ops\data_service_ops.py in <module>
#      23 from tensorflow.python.data.experimental.service import _pywrap_server_lib
#      24 from tensorflow.python.data.experimental.service import _pywrap_utils
# ---> 25 from tensorflow.python.data.ops import dataset_ops
#      26 from tensorflow.python.data.ops import options as options_lib
#      27 from tensorflow.python.data.ops import structured_function
#
# c:\Users\tan\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in <module>
#      27 from tensorflow.core.framework import graph_pb2
#      28 from tensorflow.python import tf2
# ---> 29 from tensorflow.python.data.ops import iterator_ops
#      30 from tensorflow.python.data.ops import options as options_lib
#      31 from tensorflow.python.data.ops import structured_function
#
# c:\Users\tan\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\data\ops\iterator_ops.py in <module>
#      32 from tensorflow.python.ops import gen_dataset_ops
#      33 from tensorflow.python.trackable import base as trackable
# ---> 34 from tensorflow.python.training.saver import BaseSaverBuilder
#      35 from tensorflow.python.util import _pywrap_utils
#      36 from tensorflow.python.util import deprecation
#
# c:\Users\tan\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\training\saver.py in <module>
#      30 from tensorflow.core.protobuf import saver_pb2
#      31 from tensorflow.core.protobuf import trackable_object_graph_pb2
# ---> 32 from tensorflow.python.checkpoint import checkpoint_management
#      33 from tensorflow.python.client import session
#      34 from tensorflow.python.eager import context
#
# c:\Users\tan\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\checkpoint\__init__.py in <module>
#       1 """API defining checkpoint."""
#       2
# ----> 3 from tensorflow.python.checkpoint import checkpoint_view
#
# c:\Users\tan\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\checkpoint\checkpoint_view.py in <module>
#      17
#      18 from tensorflow.core.protobuf import trackable_object_graph_pb2
# ---> 19 from tensorflow.python.checkpoint import trackable_view
#      20 from tensorflow.python.framework import errors_impl
#      21 from tensorflow.python.platform import tf_logging as logging
#
# c:\Users\tan\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\checkpoint\trackable_view.py in <module>
#      18
#      19 from tensorflow.python.trackable import base
# ---> 20 from tensorflow.python.trackable import converter
#      21 from tensorflow.python.util import object_identity
#      22 from tensorflow.python.util.tf_export import tf_export
#
# c:\Users\tan\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\trackable\converter.py in <module>
#      16
#      17
# ---> 18 from tensorflow.python.eager.polymorphic_function import saved_model_utils
#      19 from tensorflow.python.framework import dtypes
#      20 from tensorflow.python.framework import tensor_util
#
# c:\Users\tan\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\eager\polymorphic_function\saved_model_utils.py in <module>
#      34 from tensorflow.python.trackable import asset
#      35 from tensorflow.python.trackable import base as trackable
# ---> 36 from tensorflow.python.trackable import resource
#      37
#      38
#
# c:\Users\tan\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\trackable\resource.py in <module>
#      20
#      21 from tensorflow.python.eager import context
# ---> 22 from tensorflow.python.eager import def_function
#      23 from tensorflow.python.framework import ops
#      24 from tensorflow.python.trackable import base
#
# c:\Users\tan\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\eager\def_function.py in <module>
#      18
#      19 # Config Options
# ---> 20 from tensorflow.python.eager.polymorphic_function.polymorphic_function import set_dynamic_variable_creation
#      21 from tensorflow.python.eager.polymorphic_function.polymorphic_function import run_functions_eagerly
#      22 from tensorflow.python.eager.polymorphic_function.polymorphic_function import functions_run_eagerly
#
# c:\Users\tan\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py in <module>
#      74 from tensorflow.python.eager import lift_to_graph
#      75 from tensorflow.python.eager import monitoring
# ---> 76 from tensorflow.python.eager.polymorphic_function import function_spec as function_spec_lib
#      77 from tensorflow.python.eager.polymorphic_function import monomorphic_function
#      78 from tensorflow.python.eager.polymorphic_function import tracing_compiler
#
# c:\Users\tan\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\eager\polymorphic_function\function_spec.py in <module>
#      23
#      24 from tensorflow.core.function import trace_type
# ---> 25 from tensorflow.core.function.polymorphism import function_type as function_type_lib
#      26 from tensorflow.python.eager.polymorphic_function import composite_tensor_utils
#      27 from tensorflow.python.framework import composite_tensor
#
# c:\Users\tan\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\core\function\polymorphism\function_type.py in <module>
#      17 import collections
#      18 import inspect
# ---> 19 from typing import Any, Callable, Dict, Mapping, Optional, Sequence, Tuple, OrderedDict
#      20
#      21 from tensorflow.core.function import trace_type
#
# ImportError: cannot import name 'OrderedDict' from 'typing' (c:\Users\tan\AppData\Local\Programs\Python\Python37\lib\typing.py)

# %%
import tensorflow as tf
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6164\2091127585.py in <module>
# ----> 1 import tensorflow as tf
#
# c:\Users\tan\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\__init__.py in <module>
#      35 import typing as _typing
#      36
# ---> 37 from tensorflow.python.tools import module_util as _module_util
#      38 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      39
#
# c:\Users\tan\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\__init__.py in <module>
#      40
#      41 # Bring in subpackages.
# ---> 42 from tensorflow.python import data
#      43 from tensorflow.python import distribute
#      44 # from tensorflow.python import keras
#
# c:\Users\tan\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\data\__init__.py in <module>
#      19
#      20 # pylint: disable=unused-import
# ---> 21 from tensorflow.python.data import experimental
#      22 from tensorflow.python.data.ops.dataset_ops import AUTOTUNE
#      23 from tensorflow.python.data.ops.dataset_ops import Dataset
#
# c:\Users\tan\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\data\experimental\__init__.py in <module>
#      94
#      95 # pylint: disable=unused-import
# ---> 96 from tensorflow.python.data.experimental import service
#      97 from tensorflow.python.data.experimental.ops.batching import dense_to_ragged_batch
#      98 from tensorflow.python.data.experimental.ops.batching import dense_to_sparse_batch
#
# c:\Users\tan\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\data\experimental\service\__init__.py in <module>
#     417 """
#     418
# --> 419 from tensorflow.python.data.experimental.ops.data_service_ops import distribute
#     420 from tensorflow.python.data.experimental.ops.data_service_ops import from_dataset_id
#     421 from tensorflow.python.data.experimental.ops.data_service_ops import register_dataset
#
# c:\Users\tan\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\data\experimental\ops\data_service_ops.py in <module>
#      23 from tensorflow.python.data.experimental.service import _pywrap_server_lib
#      24 from tensorflow.python.data.experimental.service import _pywrap_utils
# ---> 25 from tensorflow.python.data.ops import dataset_ops
#      26 from tensorflow.python.data.ops import options as options_lib
#      27 from tensorflow.python.data.ops import structured_function
#
# c:\Users\tan\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in <module>
#      27 from tensorflow.core.framework import graph_pb2
#      28 from tensorflow.python import tf2
# ---> 29 from tensorflow.python.data.ops import iterator_ops
#      30 from tensorflow.python.data.ops import options as options_lib
#      31 from tensorflow.python.data.ops import structured_function
#
# c:\Users\tan\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\data\ops\iterator_ops.py in <module>
#      32 from tensorflow.python.ops import gen_dataset_ops
#      33 from tensorflow.python.trackable import base as trackable
# ---> 34 from tensorflow.python.training.saver import BaseSaverBuilder
#      35 from tensorflow.python.util import _pywrap_utils
#      36 from tensorflow.python.util import deprecation
#
# c:\Users\tan\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\training\saver.py in <module>
#      30 from tensorflow.core.protobuf import saver_pb2
#      31 from tensorflow.core.protobuf import trackable_object_graph_pb2
# ---> 32 from tensorflow.python.checkpoint import checkpoint_management
#      33 from tensorflow.python.client import session
#      34 from tensorflow.python.eager import context
#
# c:\Users\tan\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\checkpoint\__init__.py in <module>
#       1 """API defining checkpoint."""
#       2
# ----> 3 from tensorflow.python.checkpoint import checkpoint_view
#
# c:\Users\tan\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\checkpoint\checkpoint_view.py in <module>
#      17
#      18 from tensorflow.core.protobuf import trackable_object_graph_pb2
# ---> 19 from tensorflow.python.checkpoint import trackable_view
#      20 from tensorflow.python.framework import errors_impl
#      21 from tensorflow.python.platform import tf_logging as logging
#
# c:\Users\tan\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\checkpoint\trackable_view.py in <module>
#      18
#      19 from tensorflow.python.trackable import base
# ---> 20 from tensorflow.python.trackable import converter
#      21 from tensorflow.python.util import object_identity
#      22 from tensorflow.python.util.tf_export import tf_export
#
# c:\Users\tan\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\trackable\converter.py in <module>
#      16
#      17
# ---> 18 from tensorflow.python.eager.polymorphic_function import saved_model_utils
#      19 from tensorflow.python.framework import dtypes
#      20 from tensorflow.python.framework import tensor_util
#
# c:\Users\tan\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\eager\polymorphic_function\saved_model_utils.py in <module>
#      34 from tensorflow.python.trackable import asset
#      35 from tensorflow.python.trackable import base as trackable
# ---> 36 from tensorflow.python.trackable import resource
#      37
#      38
#
# c:\Users\tan\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\trackable\resource.py in <module>
#      20
#      21 from tensorflow.python.eager import context
# ---> 22 from tensorflow.python.eager import def_function
#      23 from tensorflow.python.framework import ops
#      24 from tensorflow.python.trackable import base
#
# c:\Users\tan\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\eager\def_function.py in <module>
#      18
#      19 # Config Options
# ---> 20 from tensorflow.python.eager.polymorphic_function.polymorphic_function import set_dynamic_variable_creation
#      21 from tensorflow.python.eager.polymorphic_function.polymorphic_function import run_functions_eagerly
#      22 from tensorflow.python.eager.polymorphic_function.polymorphic_function import functions_run_eagerly
#
# c:\Users\tan\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py in <module>
#      74 from tensorflow.python.eager import lift_to_graph
#      75 from tensorflow.python.eager import monitoring
# ---> 76 from tensorflow.python.eager.polymorphic_function import function_spec as function_spec_lib
#      77 from tensorflow.python.eager.polymorphic_function import monomorphic_function
#      78 from tensorflow.python.eager.polymorphic_function import tracing_compiler
#
# c:\Users\tan\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\eager\polymorphic_function\function_spec.py in <module>
#      23
#      24 from tensorflow.core.function import trace_type
# ---> 25 from tensorflow.core.function.polymorphism import function_type as function_type_lib
#      26 from tensorflow.python.eager.polymorphic_function import composite_tensor_utils
#      27 from tensorflow.python.framework import composite_tensor
#
# c:\Users\tan\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\core\function\polymorphism\function_type.py in <module>
#      17 import collections
#      18 import inspect
# ---> 19 from typing import Any, Callable, Dict, Mapping, Optional, Sequence, Tuple, OrderedDict
#      20
#      21 from tensorflow.core.function import trace_type
#
# ImportError: cannot import name 'OrderedDict' from 'typing' (c:\Users\tan\AppData\Local\Programs\Python\Python37\lib\typing.py)

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\tan\appdata\local\programs\python\python37\lib\site-packages (2.11.0)
# Requirement already satisfied: tensorflow-intel==2.11.0 in c:\users\tan\appdata\local\programs\python\python37\lib\site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\tan\appdata\local\programs\python\python37\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\tan\appdata\local\programs\python\python37\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\tan\appdata\local\programs\python\python37\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (24.3.25)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\tan\appdata\local\programs\python\python37\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\tan\appdata\local\programs\python\python37\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\tan\appdata\local\programs\python\python37\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.8.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\tan\appdata\local\programs\python\python37\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (18.1.1)
# Requirement already satisfied: numpy>=1.20 in c:\users\tan\appdata\local\programs\python\python37\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.20.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\tan\appdata\local\programs\python\python37\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\tan\appdata\roaming\python\python37\site-packages (from tensorflow-intel==2.11.0->tensorflow) (24.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\tan\appdata\local\programs\python\python37\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.19.6)
# Requirement already satisfied: setuptools in c:\users\tan\appdata\local\programs\python\python37\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\tan\appdata\roaming\python\python37\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\tan\appdata\local\programs\python\python37\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\tan\appdata\local\programs\python\python37\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (4.7.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\tan\appdata\local\programs\python\python37\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\tan\appdata\local\programs\python\python37\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.62.2)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in c:\users\tan\appdata\local\programs\python\python37\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.2)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in c:\users\tan\appdata\local\programs\python\python37\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in c:\users\tan\appdata\local\programs\python\python37\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\tan\appdata\local\programs\python\python37\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.31.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\tan\appdata\local\programs\python\python37\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.11.0->tensorflow) (0.42.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\tan\appdata\local\programs\python\python37\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.32.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\tan\appdata\local\programs\python\python37\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\tan\appdata\local\programs\python\python37\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.4.4)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\tan\appdata\local\programs\python\python37\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\tan\appdata\local\programs\python\python37\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\tan\appdata\local\programs\python\python37\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\tan\appdata\local\programs\python\python37\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\tan\appdata\local\programs\python\python37\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (5.4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\tan\appdata\local\programs\python\python37\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\tan\appdata\local\programs\python\python37\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\tan\appdata\local\programs\python\python37\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.0.0)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\tan\appdata\local\programs\python\python37\lib\site-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (6.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\tan\appdata\local\programs\python\python37\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tan\appdata\local\programs\python\python37\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tan\appdata\local\programs\python\python37\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tan\appdata\local\programs\python\python37\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2024.7.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\tan\appdata\local\programs\python\python37\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.1.5)
# Requirement already satisfied: zipp>=0.5 in c:\users\tan\appdata\local\programs\python\python37\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.15.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\tan\appdata\local\programs\python\python37\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\tan\appdata\local\programs\python\python37\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.2.2)
