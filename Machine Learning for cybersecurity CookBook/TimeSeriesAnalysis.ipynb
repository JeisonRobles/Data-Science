# %% [markdown]
# # TIME SERIES ANALYSIS

# %%
# !pip install statsmodels scipy
# Out:
# Collecting statsmodels
#   Downloading statsmodels-0.13.5-cp37-cp37m-win_amd64.whl.metadata (9.5 kB)
# Requirement already satisfied: scipy in c:\users\tan\appdata\local\programs\python\python37\lib\site-packages (1.7.3)
# Requirement already satisfied: pandas>=0.25 in c:\users\tan\appdata\local\programs\python\python37\lib\site-packages (from statsmodels) (1.1.5)
# Collecting patsy>=0.5.2 (from statsmodels)
#   Downloading patsy-0.5.6-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: packaging>=21.3 in c:\users\tan\appdata\roaming\python\python37\site-packages (from statsmodels) (24.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\tan\appdata\local\programs\python\python37\lib\site-packages (from statsmodels) (1.20.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\tan\appdata\roaming\python\python37\site-packages (from pandas>=0.25->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2017.2 in c:\users\tan\appdata\local\programs\python\python37\lib\site-packages (from pandas>=0.25->statsmodels) (2024.1)
# Requirement already satisfied: six in c:\users\tan\appdata\roaming\python\python37\site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
# Downloading statsmodels-0.13.5-cp37-cp37m-win_amd64.whl (9.1 MB)
#    ---------------------------------------- 9.1/9.1 MB 4.6 MB/s eta 0:00:00
# Downloading patsy-0.5.6-py2.py3-none-any.whl (233 kB)
#    ---------------------------------------- 233.9/233.9 kB 4.8 MB/s eta 0:00:00
# Installing collected packages: patsy, statsmodels
# Successfully installed patsy-0.5.6 statsmodels-0.13.5

# %%
from random import random
import matplotlib.pyplot as plt

# %%
time_series = [2 * x + random() for x in range(1,100)]

plt.plot(time_series)
